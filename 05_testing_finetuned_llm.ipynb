# %%
pip install modal
# Out:
# ...
#   Using cached modal-0.67.34-py3-none-any.whl.metadata (2.3 kB)
# ...
#
# ...
#   Using cached grpclib-0.4.7-py3-none-any.whl
# ...
#   Using cached synchronicity-0.9.5-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached types_certifi-2021.10.8.3-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached types_toml-0.10.8.20240310-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached sigtools-4.0.1-py2.py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# ...
# Using cached modal-0.67.34-py3-none-any.whl (490 kB)
# Using cached synchronicity-0.9.5-py3-none-any.whl (34 kB)
# ...
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached types_certifi-2021.10.8.3-py3-none-any.whl (2.1 kB)
# Using cached types_toml-0.10.8.20240310-py3-none-any.whl (4.8 kB)
# ...

# %%
# !modal setup
# Out:
# ⠋ Waiting for authentication in the web browser
# ⠙ Waiting for authentication in the web browser
# ⠹ Waiting for authentication in the web browser
# The web browser should have opened for you to authenticate and get an API
# token.
# If it didn't, please copy this URL into your web browser manually:
#
# ⠸ Waiting for authentication in the web browser
# ⠸ Waiting for authentication in the web browser
# https://modal.com/token-flow/tf-waqktfrS0WbcAv1daeLRoA
#
# ⠸ Waiting for authentication in the web browser
# ⠸ Waiting for authentication in the web browser
#
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ...

# %%
import modal

# %%
# !modal deploy 02_deploying_fine_tuned_llm_on_cloud
# Out:
# - Creating objects...
# \ Creating objects...
# / Creating objects...
# \ Creating objects...
# └── - Creating mount
#     d:\Domain_based_chatbot\02_deploying_fine_tuned_llm_on_cloud.py: Uploaded
#     0/1 files
# / Creating objects...
# └── | Creating mount
#     d:\Domain_based_chatbot\02_deploying_fine_tuned_llm_on_cloud.py: Uploaded
#     0/1 files
# \ Creating objects...
# └── - Creating mount
#     d:\Domain_based_chatbot\02_deploying_fine_tuned_llm_on_cloud.py: Uploaded
#     0/1 files
# - Creating objects...
# └── | Creating mount
#     d:\Domain_based_chatbot\02_deploying_fine_tuned_llm_on_cloud.py: Uploaded
#     0/1 files
# \ Creating objects...
# └── - Creating mount
#     d:\Domain_based_chatbot\02_deploying_fine_tuned_llm_on_cloud.py: Uploaded
#     0/1 files
# / Creating objects...
# └── | Creating mount
#     d:\Domain_based_chatbot\02_deploying_fine_tuned_llm_on_cloud.py: Uploaded
#     0/1 files
# | Creating objects...
# └── - Creating mount
# ...

# %%
Companion = modal.Cls.lookup("domain_based_chatbot", "Companion")
pricer = Companion()
prompt = f"""Answer the Question
Question: how far is haridwar from dehradun
Answer:
"""
reply = pricer.query.remote(prompt, 
                          session_id= "sht")
print(reply)
# Out:
# I can only assist with queries related to Healthcare, Insurance, Finance, or Retail.
